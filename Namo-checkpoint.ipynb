# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Bihar_Election_Results.csv')

# %%
df
# Out:
#       Election Year  Position                     Name  Votes Votes %  \
# 0              2010         1             Rajesh Singh  42289  29.40%
# 1              2010         2    Mukesh Kumar Kushwaha  27618  19.20%
# 2              2010         3  Dheerendra Pratap Singh  20886  14.50%
# 3              2010         4           Irshad Hussain  17747  12.40%
# 4              2010         5      Deep Narayan Mahato  14047   9.80%
# ...             ...       ...                      ...    ...     ...
# 12296      2005-Feb        15  Chandeshwar Prasad Gupt    534   0.60%
# 12297      2005-Feb        16             Tirpit Singh    498   0.60%
# 12298      2005-Feb        17        Surendra Rajbansi    437   0.50%
# 12299      2005-Feb        18       Nawin Kumar Paswan    415   0.50%
# 12300      2005-Feb        19               Ajay Kumar    407   0.50%
#
#                           Party        AC name  AC No
# 0           Janata Dal (United)  Valmiki Nagar      1
# ...

# %%
len(df['Party'].unique())
# Out:
# 222

# %%
df['Election Year'].unique()
# Out:
# array(['2010', '2015', '2005-Oct', '2005-Feb'], dtype=object)

# %%
df1=df.groupby(['Election Year'])

# %% [markdown]
# Determine the winning party for every election at the state level. A party which has the highest total votes is considered the winner here.

# %%
df1.first().count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df1.first().count()
#
# NameError: name 'df1' is not defined

# %% [markdown]
# # For The Feb-2005

# %%
feb=df1.get_group('2005-Feb')

# %%
feb
# Out:
#       Election Year  Position                     Name  Votes Votes %  \
# 9108       2005-Feb         1             Rajesh Singh  19389  30.60%
# 9109       2005-Feb         2           Ramadhar Yadav  13287  21.00%
# 9110       2005-Feb         3    Mukesh Kumar Kushwaha  10865  17.20%
# 9111       2005-Feb         4        Arun Kumar Tiwari   5073   8.00%
# 9112       2005-Feb         5      Bawwan Prasad Yadav   3320   5.30%
# ...             ...       ...                      ...    ...     ...
# 12296      2005-Feb        15  Chandeshwar Prasad Gupt    534   0.60%
# 12297      2005-Feb        16             Tirpit Singh    498   0.60%
# 12298      2005-Feb        17        Surendra Rajbansi    437   0.50%
# 12299      2005-Feb        18       Nawin Kumar Paswan    415   0.50%
# 12300      2005-Feb        19               Ajay Kumar    407   0.50%
#
#                       Party        AC name  AC No
# 9108   Rashtriya Janata Dal  Valmiki Nagar      1
# ...

# %%
feb['Party'].unique()
# Out:
# array(['Rashtriya Janata Dal', 'Samajwadi Party', 'Independent',
#        'Lok Jan Shakti Party', 'Samata Party',
#        'Nationalist Congress Party', 'Bahujan Samaj Party',
#        'National Loktantrik Party', 'Janata Dal (United)',
#        'Communist Party Of India (MARXIST-LENINIST) (LIBERATION)',
#        'Rashtriya Lok Dal', 'Shiv Sena', 'Bharatiya Janta Party',
#        'Indian National Congress', 'Samajwadi Janata Party (RASHTRIYA)',
#        'Apna Dal', 'Jai Jawan Jai Kisan Mazdoor Congress',
#        'Indian Justice Party', 'Lok Dal',
#        'Communist Party Of India (MARXIST)', 'Jharkhand Party',
#        'Rashtriya Krantikari Samajwadi Party', 'Samajwadi Jan Parishad',
#        'Bajjikanchal Vikas Party', 'Krantikari Samyavadi Party',
#        'Akhil Bharatiya Ashok Sena', 'Communist Party Of India',
#        'Akhil Bharat Hindu Mahasabha', 'Bharat Mangalam Parishad',
#        'Gondvana Gantantra Party', 'Lok Sewa Dal',
# ...

# %%
febp=feb.groupby(['Party']).sum()

# %%
febp
# Out:
#                                       Position  Votes  AC No
# Party
# Adarsh Political Party                      11    736    187
# Akhand Jharkhand People's Front             76   9800   1114
# Akhil Bharat Hindu Mahasabha                55   4603    565
# Akhil Bharatiya Ashok Sena                  12    858     22
# Akhil Bharatiya Desh Bhakt Morcha           16    326    193
# ...                                        ...    ...    ...
# Sarvhara Dal                                 8   1238    170
# Shiv Sena                                  353  25698   3473
# Shoshit Samaj Dal (AKHIL BAHARATIYA)        75   9303   1505
# Shoshit Samaj Party                         37   3729    608
# Suheldev Bhartiya Samaj Party               21  13655    606
#
# [66 rows x 3 columns]

# %%
result1=febp.sort_values(by=['Votes'], ascending=False)

# %%
result1
# Out:
#                                    Position    Votes   AC No
# Party
# Rashtriya Janata Dal                    431  6140223   25719
# Independent                           15010  3957945  181641
# Janata Dal (United)                     318  3564930   16825
# Lok Jan Shakti Party                    585  3091173   21837
# Bharatiya Janta Party                   226  2686290   12280
# ...                                     ...      ...     ...
# Indian Union Muslim League               13      758     140
# Adarsh Political Party                   11      736     187
# Sanatan Samaj Party                      15      705     195
# Bharat Mangalam Parishad                 15      397      28
# Akhil Bharatiya Desh Bhakt Morcha        16      326     193
#
# [66 rows x 3 columns]

# %%
result1.head(8)
# Out:
#                           Position    Votes   AC No
# Party
# Rashtriya Janata Dal           431  6140223   25719
# Independent                  15010  3957945  181641
# Janata Dal (United)            318  3564930   16825
# Lok Jan Shakti Party           585  3091173   21837
# Bharatiya Janta Party          226  2686290   12280
# Indian National Congress       305  1223835   10190
# Bahujan Samaj Party           1434  1080745   28913
# Samajwadi Party               1167   658791   16483

# %% [markdown]
# # For Oct-2005

# %%
Oct=df1.get_group('2005-Oct')

# %%
Oct
# Out:
#      Election Year  Position                            Name  Votes Votes %  \
# 6973      2005-Oct         1                    Rajesh Singh  19164  32.30%
# 6974      2005-Oct         2                  Ramadhar Yadav  17700  29.80%
# 6975      2005-Oct         3           Mukesh Kumar Kushwaha  11839  20.00%
# 6976      2005-Oct         4                   Arthraj Yadav   4285   7.20%
# 6977      2005-Oct         5  Krishna Bihari Prasad Kushwaha   1649   2.80%
# ...            ...       ...                             ...    ...     ...
# 9103      2005-Oct         3              Shyam Kishor Singh   4508   5.60%
# 9104      2005-Oct         4                     Bipul Kumar   2123   2.70%
# 9105      2005-Oct         5            Ramesh Chandra Raman   1629   2.00%
# 9106      2005-Oct         6                  Babulal Prasad    967   1.20%
# 9107      2005-Oct         7                    Tripit Singh    877   1.10%
#
#                           Party        AC name  AC No
# ...

# %%
Oct['Party'].unique()
# Out:
# array(['Rashtriya Janata Dal', 'Samajwadi Party', 'Janata Dal (United)',
#        'Bahujan Samaj Party', 'National Loktantrik Party',
#        'Lok Jan Shakti Party', 'Independent',
#        'Communist Party Of India (MARXIST-LENINIST) (LIBERATION)',
#        'Indian National Congress', 'Indian Justice Party',
#        'Bharatiya Janta Party', 'Buddhiviveki Vikas Party',
#        'Samata Party', 'Jai Jawan Jai Kisan Mazdoor Congress',
#        'Nationalist Congress Party', 'Communist Party Of India',
#        'Communist Party Of India (MARXIST)', 'Akhil Jan Vikas Dal',
#        'Muslim League Kerala State Committee', 'Gondvana Gantantra Party',
#        'Bharatiya Ekta Dal', 'Akhil Bharat Hindu Mahasabha',
#        'All India Forward Bloc', 'Apna Dal', 'Bharat Mangalam Parishad',
#        'Samajwadi Janata Party (RASHTRIYA)', 'Samajik Jantantrik Party',
#        'Rashtriya Lok Dal', 'Bharatiya Momin Front',
#        'Bajjikanchal Vikas Party', 'Janata Dal (Secular)',
# ...

# %%
Octp=Oct.groupby(['Party']).sum()

# %%
Octp
# Out:
#                                                     Position    Votes  AC No
# Party
# Akhil Bharat Hindu Mahasabha                              47     5135    614
# Akhil Bharatiya Ashok Sena                                 6     1450    201
# Akhil Bharatiya Desh Bhakt Morcha                         15     2690    333
# Akhil Bharatiya Jan Sangh                                 79     5790   1556
# Akhil Jan Vikas Dal                                       38    49869    826
# All India Forward Bloc                                    15    42749    387
# Ambedkar National Congress                                59    14396   1214
# Amra Bangalee                                             17     3104    269
# Apna Dal                                                  67     9179   1077
# Awami Party                                                9     1833    236
# Bahujan Samaj Party                                     1156   981464  26484
# ...

# %%
result2=Octp.sort_values(by=['Votes'], ascending=False)

# %%
result2
# Out:
#                                                     Position    Votes  AC No
# Party
# Rashtriya Janata Dal                                     319  5525081  21364
# Janata Dal (United)                                      209  4819759  17158
# Bharatiya Janta Party                                    173  3686720  12351
# Lok Jan Shakti Party                                     669  2615901  24204
# Independent                                             5505  2065744  95176
# Indian National Congress                                 104  1435449   5737
# Bahujan Samaj Party                                     1156   981464  26484
# Samajwadi Party                                         1002   594266  17285
# Communist Party Of India (MARXIST-LENINIST) (LI...       421   559326  11128
# Communist Party Of India                                 108   491689   4367
# Nationalist Congress Party                                20   186936   1112
# ...

# %%
result2.head(8)
# Out:
#                           Position    Votes  AC No
# Party
# Rashtriya Janata Dal           319  5525081  21364
# Janata Dal (United)            209  4819759  17158
# Bharatiya Janta Party          173  3686720  12351
# Lok Jan Shakti Party           669  2615901  24204
# Independent                   5505  2065744  95176
# Indian National Congress       104  1435449   5737
# Bahujan Samaj Party           1156   981464  26484
# Samajwadi Party               1002   594266  17285

# %% [markdown]
# # For 2010

# %%
two10=df1.get_group('2010')

# %%
two10
# Out:
#      Election Year  Position                         Name  Votes Votes %  \
# 0             2010         1                 Rajesh Singh  42289  29.40%
# 1             2010         2        Mukesh Kumar Kushwaha  27618  19.20%
# 2             2010         3      Dheerendra Pratap Singh  20886  14.50%
# 3             2010         4               Irshad Hussain  17747  12.40%
# 4             2010         5          Deep Narayan Mahato  14047   9.80%
# ...            ...       ...                          ...    ...     ...
# 3518          2010         8  Shashi Bhushan Prasad Singh   3508   3.20%
# 3519          2010         9            Onkarnath Barnwal   2729   2.50%
# 3520          2010        10             Balmakund Mandal   1798   1.70%
# 3521          2010        11                 Naresh Singh   1355   1.30%
# 3522          2010        12                 Kalu Marandi   1329   1.20%
#
#                                                   Party        AC name  AC No
# ...

# %%
two10['Party'].unique()
# Out:
# array(['Janata Dal (United)', 'Rashtriya Janata Dal',
#        'Bahujan Samaj Party', 'Indian National Congress', 'Independent',
#        'Janvadi Party (Socialist)', 'Nationalist Congress Party',
#        'Bharatiya Jantantrik Janta Dal', 'Bharatiya Janta Party',
#        'Communist Party Of India (MARXIST-LENINIST) (LIBERATION)',
#        'Samajwadi Party', 'Samajwadi Janata Party (RASHTRIYA)',
#        'Bharat Vikas Morcha', 'Suheldev Bhartiya Samaj Party',
#        'Akhil Bharatiya Ashok Sena', 'Indian Justice Party',
#        'Rashtriya Krantikari Janata Party', 'Rashtra Sewa Dal',
#        'Communist Party Of India (MARXIST)', 'Lok Jan Shakti Party',
#        'Communist Party Of India', 'Janata Dal (Secular)',
#        'Vanchitsamaj Insaaf Party', 'Jharkhand Mukti Morcha',
#        'Garib Vikas Party', 'Indian National Green Party',
#        'All India Forward Bloc', 'Krantikari Samyavadi Party',
#        'Smast Bhartiya Party', 'All India Forward Bloc (Subhasist)',
# ...

# %%
two10p=two10.groupby(['Party']).sum()

# %%
two10p
# Out:
#                                              Position  Votes  AC No
# Party
# Akhand Bharat Samaj Party                           8   1690    140
# Akhil Bharat Hindu Mahasabha                       45   2493    327
# Akhil Bharatiya Ashok Sena                         75   4227    440
# Akhil Bharatiya Desh Bhakt Morcha                  15    732    206
# Akhil Bharatiya Hind Kranti Party                   8   1940    204
# ...                                               ...    ...    ...
# Socialist Janta Party                              22   4374    166
# Socialist Party (LOHIA)                            20   3054    341
# Socialist Unity Centre Of India (COMMUNIST)       125  13696   1304
# Suheldev Bhartiya Samaj Party                      61  15437    815
# Vanchitsamaj Insaaf Party                         103   9454    906
#
# [90 rows x 3 columns]

# %%
result3=two10p.sort_values(by=['Votes'], ascending=False)

# %%
result3
# Out:
#                                    Position    Votes   AC No
# Party
# Janata Dal (United)                     172  6561906   17669
# Rashtriya Janata Dal                    351  5475656   20664
# Bharatiya Janta Party                   119  4790436   11837
# Independent                           13098  3842812  162144
# Indian National Congress               1006  2431477   29506
# ...                                     ...      ...     ...
# Akhil Bharatiya Desh Bhakt Morcha        15      732     206
# Pragtisheel Manav Samaj Party            17      588     205
# Samajwadi Jan Parishad                   18      567     209
# Sarvhara Dal                             11      558     241
# Alpjan Samaj Party                       22      520     208
#
# [90 rows x 3 columns]

# %%
result3.head(8)
# Out:
#                             Position    Votes   AC No
# Party
# Janata Dal (United)              172  6561906   17669
# Rashtriya Janata Dal             351  5475656   20664
# Bharatiya Janta Party            119  4790436   11837
# Independent                    13098  3842812  162144
# Indian National Congress        1006  2431477   29506
# Lok Jan Shakti Party             184  1957232    8842
# Bahujan Samaj Party             1687   933947   29085
# Nationalist Congress Party      1614   528575   19905

# %% [markdown]
# # For 2015

# %%
two15=df1.get_group('2015')

# %%
two15
# Out:
#      Election Year  Position                                      Name  Votes  \
# 3523          2015         1  Dhirendra Pratap Singh Alias Rinku Singh  66860
# 3524          2015         2                            Irshad Hussain  33280
# 3525          2015         3                           Surendra Prasad  32855
# 3526          2015         4                              Rajesh Singh  11472
# 3527          2015         5                             Altaf Hussain  11097
# ...            ...       ...                                       ...    ...
# 6968          2015         8                        Manoj Kumar Pandey   2309
# 6969          2015         9                      Bajrang Bihari Singh   2233
# 6970          2015        10                             Abhinav Singh   1782
# 6971          2015        11                               Nandu Yadav   1343
# 6972          2015        12                            Rajendra Yadav   1121
#
# ...

# %%
two15['Party'].unique()
# Out:
# array(['Independent', 'Indian National Congress',
#        'Rashtriya Lok Samta Party', 'Samajwadi Party',
#        'Bahujan Samaj Party', 'Sarvajan Kalyan Loktantrik Party',
#        'Shiv Sena',
#        'Communist Party Of India (Marxist-Leninist) (Liberation)',
#        'Garib Janta Dal (Secular)', 'Bharatiya Janta Party',
#        'Nationalist Congress Party', 'Jan Adhikar Party (Loktantrik)',
#        'Bharatiya Ekta Dal', 'Janta Dal Rashtravadi',
#        'Bahujan Mukti Party', 'Janata Dal (United)',
#        'Jharkhand Mukti Morcha', 'Rashtriya Janata Dal',
#        'Communist Party Of India', 'Rashtriya Jankranti Party',
#        'Gareeb Aadmi Party', 'Communist Party Of India (MARXIST)',
#        'National Janta Party (Indian)', 'Rashtriya Samanta Dal',
#        'Bhartiya Lokmat Rashtrwadi Party',
#        'Jammu & Kashmir National Panthers Party', 'Lok Jan Shakti Party',
#        'Aarakshan Virodhi Party', 'Aam Janata Party',
# ...

# %%
two15p=two15.groupby(['Party']).sum()

# %%
two15p
# Out:
#                                       Position  Votes  AC No
# Party
# Aadarsh Mithila Party                       26   2161     70
# Aam Janata Party                            97  10155   1366
# Aap Aur Hum Party                          173  20663   1821
# Aarakshan Virodhi Party                    145  12128   1429
# Akhil Bharat Hindu Mahasabha               199  12268   1545
# ...                                        ...    ...    ...
# Swaraj Party (Loktantrik)                   10  11219    424
# Swatantra Samaj Party                       24   1864    213
# The National Road Map Party Of India        82   9809    525
# Vanchitsamaj Insaaf Party                   97   5380    653
# Vyabasayi Kisan Alpasankhyak Morcha         44   3535    814
#
# [157 rows x 3 columns]

# %%
result4=two15p.sort_values(by=['Votes'], ascending=False)

# %%
result4
# Out:
#                                     Position    Votes   AC No
# Party
# Bharatiya Janta Party                    263  9308015   17747
# Rashtriya Janata Dal                     124  6995509   12401
# Janata Dal (United)                      133  6416414   12289
# Independent                             9993  3580953  141150
# Indian National Congress                  57  2539638    4816
# ...                                      ...      ...     ...
# Praja Raj Party                           16      400     128
# All India Forward Bloc (Subhasist)        25      382      62
# Deshi Kisan Party                         11      346     237
# Congress (Secular)                        26      330     200
# National Youth Party                      15      242     211
#
# [157 rows x 3 columns]

# %%
result4.head(8)
# Out:
#                                   Position    Votes   AC No
# Party
# Bharatiya Janta Party                  263  9308015   17747
# Rashtriya Janata Dal                   124  6995509   12401
# Janata Dal (United)                    133  6416414   12289
# Independent                           9993  3580953  141150
# Indian National Congress                57  2539638    4816
# Lok Jan Shakti Party                    88  1840834    5489
# Rashtriya Lok Samta Party               48   976787    3161
# Hindustani Awam Morcha (Secular)        45   864856    3109

# %%
file_name='top11.xlsx'
df2.to_excel(file_name)
